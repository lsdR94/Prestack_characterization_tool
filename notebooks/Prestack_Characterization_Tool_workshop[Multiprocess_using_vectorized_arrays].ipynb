# %%
import os
import numpy as np
import segyio
from scipy import stats
from multiprocessing import Pool

np.set_printoptions(threshold=np.inf) # Print the entire dataframe

from shutil import copyfile

# %% [markdown]
# # Data to use

# %%
# Seismic data: SEG-Y format
near_stack = os.path.join("..", "data", "NS2950-2180_3000-2230.sgy")
mid_stack = os.path.join("..", "data", "MS2950-2180_3000-2230.sgy")
far_stack = os.path.join("..", "data", "FS2950-2180_3000-2230.sgy")

# To store G and I
g_i = os.path.join("..", "data", "GradInter.sgy")
# Wells data: txt format
wells_path = '../data/wells_info.txt'

# Store the seismic data in a list
gather_path = [near_stack, mid_stack, far_stack]

# %% [markdown]
# # Input parameters to work with

# %%
# Name of the survery to display in the results
seismic_survey = 'POSEIDON 3D'

# Name and path of the merged SEG-Y file
merged_stacks = os.path.join("..", "data", "NMF2950-2180_3000-2230.sgy")

# Gradient file (SEGY)
gradient_segy = os.path.join("..", "data", "gradient.sgy")
# Intercept file (SEGY)
intercept_segy = os.path.join("..", "data", "intercept.sgy")
# Intercept file (SEGY)
rvalue_segy = os.path.join("..", "data", "correlation_c.sgy")
# Intercept file (SEGY)
pvalue_segy = os.path.join("..", "data", "pvalue.sgy")
# Intercept file (SEGY)
stderr_segy = os.path.join("..", "data", "standard_dev.sgy")

# Angle between the gathers given
angle_bet_gathers = 12

# Making a list with the angle of the gathers
angle_list = []
angle = angle_bet_gathers
for file in range(len(gather_path)):
    angle_list = angle_list + [angle]
    angle = angle + angle_bet_gathers

# %% [markdown]
# # Merging the partial angle stacks

# %%
def merging_stacks(list_of_gathers, merged_file_path, list_of_angles):
    
    """
    
    source1: https://github.com/equinor/segyio/blob/master/python/examples/make-file.py
    source2: https://github.com/equinor/segyio/blob/master/python/segyio/tracefield.py
    
    """
    
    # Validating the files
#    for file in list_of_gathers:
#        if file_validation(file) == True:
#            print(f"{file} has been validated")
#        else:
#            return(f"Unsuccessful validation: {file_validation(file)}")
    
    # Making the offset array
    offsts = np.array(list_of_angles)

    # Initializing the stacks
    with segyio.open(list_of_gathers[0]) as f, segyio.open(list_of_gathers[1]) as g, segyio.open(list_of_gathers[2]) as h:
        
        # Spec function to build the new segy
        spec = segyio.spec()
        spec.sorting = f.sorting
        spec.format = 1
        spec.samples = f.samples
        spec.ilines = f.ilines
        spec.xlines = f.xlines
        spec.offsets = offsts

        # Initializing the merged one
        with segyio.create(merged_file_path, spec) as s:
        
            # Index for the merge headers and trace
            merge_index = 0
            # Index for the original file's headers and trace
            stack_index = 0
            # For loop to set parameters according to the seismic lines and offset
            for il in spec.ilines:
                for xl in spec.xlines:
                    for offset in spec.offsets:
                        # Assigning headers [byte]
                        s.header[merge_index] = {segyio.su.tracl  : f.header[stack_index][1],
                                                 segyio.su.tracr  : f.header[stack_index][5],
                                                 segyio.su.fldr   : f.header[stack_index][9],
                                                 segyio.su.cdp    : f.header[stack_index][21],
                                                 segyio.su.cdpt   : f.header[stack_index][25],
                                                 segyio.su.offset : offset, # 37
                                                 segyio.su.scalco : f.header[stack_index][71],
                                                 segyio.su.ns     : f.header[stack_index][115],
                                                 segyio.su.dt     : f.header[stack_index][117],
                                                 segyio.su.cdpx   : f.header[stack_index][181],
                                                 segyio.su.cdpy   : f.header[stack_index][185],
                                                 segyio.su.iline  : il,  # 189
                                                 segyio.su.xline  : xl}  # 193
                        if offset == list_of_angles[0]:
                            stack = f # near
                        if offset == list_of_angles[1]:
                            stack = g # mid
                        if offset == list_of_angles[2]:
                            stack = h # far                   
                        
                        # Copying the amplitudes from each stack
                        s.trace[merge_index] = stack.trace[stack_index]
                        
                        merge_index += 1
                    stack_index += 1
                
    return (f"Successful merge. New SEG-Y file path: {merged_file_path}")

# %%
merging_stacks(gather_path, merged_stacks, angle_list)
# Out:
# 'Successful merge. New SEG-Y file path: ../data/NMF2950-2180_3000-2230.sgy'

# %% [markdown]
# # First version of multiprocess avo attributes [21 min]
# ## Doing:
# - Builds the SEG-Y to store the data from Scipy's [gradient, intercept, rvalue, pvalue, stderr]
# - Calculates and stores AVO attributes and it's statistical parameters in the SEG-Ys previously mentioned
# - Multiprocess uses Maxtaskperchild and chunksize = 1

# %% [markdown]
# ## Making the SEG-Y files to store the AVO attributes

# %%
def avo_storing_files(list_of_gathers, gradient_path, intercept_path, rvalue_path, pvalue_path, stderr_path): 
    # Initializing the stacks
    with segyio.open(list_of_gathers[0]) as f:
        
        # Spec function to build the new segy
        spec = segyio.tools.metadata(f)

        # Initializing the merged one
        with segyio.create(gradient_path, spec) as gradient:

            # Assigning headers [byte]
            gradient.text[0] = f.text[0]
            gradient.bin = f.bin
            gradient.header = f.header
            gradient.trace = f.trace
            
        print(f"Successful construction. Gradient path: ({gradient_path})")
            
    
    # Making copies of the new segy
    copyfile(gradient_path, intercept_path)
    print(f"Successful construction. Intercept path: ({intercept_path})")
    copyfile(gradient_path, rvalue_path)
    print(f"Successful construction. Correlation coeficient path: ({rvalue_path})")
    copyfile(gradient_path, pvalue_path)
    print(f"Successful construction. Pvalue path: ({pvalue_path})")
    copyfile(gradient_path, stderr_path)
    print(f"Successful construction. Standard Deviation path: ({stderr_path})")

    return

# %%
avo_storing_files(gather_path, gradient_segy, intercept_segy, rvalue_segy, pvalue_segy, stderr_segy)
# Out:
# Successful construction. Gradient path: (../data/gradient.sgy)
# Successful construction. Intercept path: (../data/intercept.sgy)
# Successful construction. Correlation coeficient path: (../data/correlation_c.sgy)
# Successful construction. Pvalue path: (../data/pvalue.sgy)
# Successful construction. Standard Deviation path: (../data/standard_dev.sgy)

# %% [markdown]
# ## Function to give arguments to the pool

# %%
def input_generator(gather_file, list_of_angles, 
                    gradient_path, intercept_path, rvalue_path, pvalue_path, stderr_path):
    """
    
    """
    index = 0
    with segyio.open(gather_file, "r") as gather:
        for iline_number in gather.ilines:
            for xline_number in gather.xlines:
                    yield [gather_file, list_of_angles, iline_number, xline_number, index, 
                           gradient_path, intercept_path, rvalue_path, pvalue_path, stderr_path]
                    index += 1
#### test it
#input_args = input_generator(merged_stacks, angle_list, 
#                             gradient_segy, intercept_segy, rvalue_segy, pvalue_segy, stderr_segy)
#for row in input_args:
#    print(row)

# %% [markdown]
# ## Function to compute the AVO attributes by trace

# %% [markdown]
# ### Second edition: vectorized function
# the function below computes and stores the data because of this hypothesis: if two functions are applied, the one receiving the data could represent a lost of ram!!

# %%
def  AVO_attributes_computation_2(generator_list):
    
    """
    
    """
    # Parameters to use in the functions
    gather_file = generator_list[0]
    list_of_angles = generator_list[1]
    iline_number = generator_list[2]
    xline_number = generator_list[3]
    index = generator_list[4]
    intercept_file = generator_list[5]
    gradient_file = generator_list[6]
    rvalue_file = generator_list[7]
    pvalue_file = generator_list[8]
    stderr_file = generator_list[9]
    
    # Initializing the sin(angle) list
    sins = []
    
    # Opening the gather to: 
                            #1) Create an empty array to store the values within the gather file
                            #2) Make multiple arrays to be used by segyio's trace function
    with segyio.open(gather_file, "r") as gather:
        gradient = np.zeros([len(gather.samples), ], dtype = "float32")
        intercept = np.zeros([len(gather.samples), ], dtype = "float32")
        rvalue = np.zeros([len(gather.samples), ], dtype = "float32")#Correlation coefficient.
        pvalue = np.zeros([len(gather.samples), ], dtype = "float32")
        stderr = np.zeros([len(gather.samples), ], dtype = "float32") #Standard error of the estimated gradient.
        
        # For loot to append the values for sins and to store the amplitudes in an array(3,1501)
        for angle in list_of_angles:
            sins += [np.sin(np.radians(angle)) * np.sin(np.radians(angle))]
            
            # If the angle is the first, then initialize the amp array
            if angle == list_of_angles[0]:
                amp = gather.gather[iline_number, xline_number, angle].reshape(len(gather.samples), 1)
            
            # If it's not the first angle in the list, concatenate to an existing variable (amp)
            else:
                amp = np.concatenate((amp, 
                                      gather.gather[iline_number, xline_number, angle].reshape(len(gather.samples), 
        
                                                                                               1)),axis=1)
        # the amp is was reshaped to (3, 1501) in order to introduce the amplitudes of a slice in the
        # Scipy function: has been VECTORIZED!!
        
        # For loop to select and to introduce values to Scipy's
        for row in range(amp.shape[0]):
            gradient[row], intercept[row], rvalue[row], pvalue[row], stderr[row] = stats.linregress(sins, amp[row])
        
    # Storing the data: Opening and closing the segy's. This should improve the perfomance of the function
    with segyio.open(gradient_file, "r+") as gradient_segy:
        gradient_segy.trace[index] = gradient

    with segyio.open(intercept_file, "r+") as intercept_segy:
        intercept_segy.trace[index] = intercept

    with segyio.open(rvalue_file, "r+") as rvalue_segy:
        rvalue_segy.trace[index] = rvalue

    with segyio.open(pvalue_file, "r+") as pvalue_segy:
        pvalue_segy.trace[index] = pvalue

    with segyio.open(stderr_file, "r+") as stderr_segy:
            stderr_segy.trace[index] = stderr
    
    print(f"AVO attributes for trace number {index}, [{iline_number},{xline_number}], has been stored successfully")
    return

#test it
#AVO_attributes_computation_2(merged_stacks, 2950, 2180, angle_list, 0,
#                             gradient_segy, intercept_segy, rvalue_segy, pvalue_segy, stderr_segy)
## TASTE it (2)
#input_args = input_generator(merged_stacks, angle_list, 
#                             gradient_segy, intercept_segy, rvalue_segy, pvalue_segy, stderr_segy)
#
#for row in input_args:
#    print(AVO_attributes_computation_2(row))

# %% [markdown]
# ## Integrating the previous functions [MP]

# %%
def avo_storeputation(gather_file, list_of_angles, 
                      gradient_file, intercept_file, rvalue_file, pvalue_file, stderr_file):
    
    input_args = input_generator(merged_stacks, angle_list, 
                             gradient_segy, intercept_segy, rvalue_segy, pvalue_segy, stderr_segy)
    
    if __name__ == "__main__":
        p = Pool(maxtasksperchild=1)
        p.map(AVO_attributes_computation_2, input_args, chunksize=1)

# %%
avo_storeputation(merged_stacks, angle_list,
                  gradient_segy, intercept_segy, rvalue_segy, pvalue_segy, stderr_segy)
# Out:
# AVO attributes for trace number 2, [2950,2182], has been stored successfully
# AVO attributes for trace number 0, [2950,2180], has been stored successfully
# AVO attributes for trace number 3, [2950,2183], has been stored successfully
# AVO attributes for trace number 1, [2950,2181], has been stored successfully
# AVO attributes for trace number 4, [2950,2184], has been stored successfully
# AVO attributes for trace number 7, [2950,2187], has been stored successfully
# AVO attributes for trace number 5, [2950,2185], has been stored successfully
# AVO attributes for trace number 6, [2950,2186], has been stored successfully
# AVO attributes for trace number 8, [2950,2188], has been stored successfully
# AVO attributes for trace number 9, [2950,2189], has been stored successfully
# AVO attributes for trace number 10, [2950,2190], has been stored successfully
# AVO attributes for trace number 11, [2950,2191], has been stored successfully
# AVO attributes for trace number 12, [2950,2192], has been stored successfully
# AVO attributes for trace number 13, [2950,2193], has been stored successfully
# AVO attributes for trace number 14, [2950,2194], has been stored successfully
# AVO attributes for trace number 15, [2950,2195], has been stored successfully
# AVO attributes for trace number 17, [2950,2197], has been stored successfully
# AVO attributes for trace number 16, [2950,2196], has been stored successfully
# AVO attributes for trace number 18, [2950,2198], has been stored successfully
# AVO attributes for trace number 19, [2950,2199], has been stored successfully
# AVO attributes for trace number 20, [2950,2200], has been stored successfully
# AVO attributes for trace number 21, [2950,2201], has been stored successfully
# AVO attributes for trace number 22, [2950,2202], has been stored successfully
# AVO attributes for trace number 23, [2950,2203], has been stored successfully
# AVO attributes for trace number 25, [2950,2205], has been stored successfully
# AVO attributes for trace number 24, [2950,2204], has been stored successfully
# AVO attributes for trace number 26, [2950,2206], has been stored successfully
# AVO attributes for trace number 27, [2950,2207], has been stored successfully
# AVO attributes for trace number 28, [2950,2208], has been stored successfully
# AVO attributes for trace number 29, [2950,2209], has been stored successfully
# AVO attributes for trace number 30, [2950,2210], has been stored successfully
# AVO attributes for trace number 31, [2950,2211], has been stored successfully
# AVO attributes for trace number 33, [2950,2213], has been stored successfully
# AVO attributes for trace number 32, [2950,2212], has been stored successfully
# AVO attributes for trace number 34, [2950,2214], has been stored successfully
# AVO attributes for trace number 35, [2950,2215], has been stored successfully
# AVO attributes for trace number 36, [2950,2216], has been stored successfully
# AVO attributes for trace number 37, [2950,2217], has been stored successfully
# AVO attributes for trace number 38, [2950,2218], has been stored successfully
# AVO attributes for trace number 39, [2950,2219], has been stored successfully
# AVO attributes for trace number 40, [2950,2220], has been stored successfully
# AVO attributes for trace number 42, [2950,2222], has been stored successfully
# AVO attributes for trace number 41, [2950,2221], has been stored successfully
# AVO attributes for trace number 43, [2950,2223], has been stored successfully
# AVO attributes for trace number 44, [2950,2224], has been stored successfully
# AVO attributes for trace number 45, [2950,2225], has been stored successfully
# AVO attributes for trace number 46, [2950,2226], has been stored successfully
# AVO attributes for trace number 47, [2950,2227], has been stored successfully
# AVO attributes for trace number 48, [2950,2228], has been stored successfully
# AVO attributes for trace number 49, [2950,2229], has been stored successfully
# AVO attributes for trace number 50, [2950,2230], has been stored successfully
# AVO attributes for trace number 51, [2951,2180], has been stored successfully
# AVO attributes for trace number 52, [2951,2181], has been stored successfully
# AVO attributes for trace number 53, [2951,2182], has been stored successfully
# AVO attributes for trace number 54, [2951,2183], has been stored successfully
# AVO attributes for trace number 55, [2951,2184], has been stored successfully
# AVO attributes for trace number 56, [2951,2185], has been stored successfully
# AVO attributes for trace number 57, [2951,2186], has been stored successfully
# AVO attributes for trace number 58, [2951,2187], has been stored successfully
# AVO attributes for trace number 59, [2951,2188], has been stored successfully
# AVO attributes for trace number 60, [2951,2189], has been stored successfully
# AVO attributes for trace number 61, [2951,2190], has been stored successfully
# AVO attributes for trace number 62, [2951,2191], has been stored successfully
# AVO attributes for trace number 63, [2951,2192], has been stored successfully
# AVO attributes for trace number 64, [2951,2193], has been stored successfully
# AVO attributes for trace number 65, [2951,2194], has been stored successfully
# AVO attributes for trace number 66, [2951,2195], has been stored successfully
# AVO attributes for trace number 67, [2951,2196], has been stored successfully
# AVO attributes for trace number 68, [2951,2197], has been stored successfully
# AVO attributes for trace number 69, [2951,2198], has been stored successfully
# AVO attributes for trace number 70, [2951,2199], has been stored successfully
# AVO attributes for trace number 71, [2951,2200], has been stored successfully
# AVO attributes for trace number 72, [2951,2201], has been stored successfully
# AVO attributes for trace number 73, [2951,2202], has been stored successfully
# AVO attributes for trace number 74, [2951,2203], has been stored successfully
# AVO attributes for trace number 75, [2951,2204], has been stored successfully
# AVO attributes for trace number 76, [2951,2205], has been stored successfully
# AVO attributes for trace number 77, [2951,2206], has been stored successfully
# AVO attributes for trace number 78, [2951,2207], has been stored successfully
# AVO attributes for trace number 79, [2951,2208], has been stored successfully
# AVO attributes for trace number 80, [2951,2209], has been stored successfully
# AVO attributes for trace number 81, [2951,2210], has been stored successfully
# AVO attributes for trace number 82, [2951,2211], has been stored successfully
# AVO attributes for trace number 83, [2951,2212], has been stored successfully
# AVO attributes for trace number 84, [2951,2213], has been stored successfully
# AVO attributes for trace number 85, [2951,2214], has been stored successfully
# AVO attributes for trace number 86, [2951,2215], has been stored successfully
# AVO attributes for trace number 87, [2951,2216], has been stored successfully
# AVO attributes for trace number 89, [2951,2218], has been stored successfully
# AVO attributes for trace number 88, [2951,2217], has been stored successfully
# AVO attributes for trace number 90, [2951,2219], has been stored successfully
# AVO attributes for trace number 91, [2951,2220], has been stored successfully
# AVO attributes for trace number 92, [2951,2221], has been stored successfully
# AVO attributes for trace number 93, [2951,2222], has been stored successfully
# AVO attributes for trace number 94, [2951,2223], has been stored successfully
# AVO attributes for trace number 95, [2951,2224], has been stored successfully
# AVO attributes for trace number 96, [2951,2225], has been stored successfully
# AVO attributes for trace number 97, [2951,2226], has been stored successfully
# AVO attributes for trace number 98, [2951,2227], has been stored successfully
# AVO attributes for trace number 99, [2951,2228], has been stored successfully
# AVO attributes for trace number 100, [2951,2229], has been stored successfully
# AVO attributes for trace number 101, [2951,2230], has been stored successfully
# AVO attributes for trace number 102, [2952,2180], has been stored successfully
# AVO attributes for trace number 103, [2952,2181], has been stored successfully
# AVO attributes for trace number 104, [2952,2182], has been stored successfully
# AVO attributes for trace number 105, [2952,2183], has been stored successfully
# AVO attributes for trace number 106, [2952,2184], has been stored successfully
# AVO attributes for trace number 107, [2952,2185], has been stored successfully
# AVO attributes for trace number 108, [2952,2186], has been stored successfully
# AVO attributes for trace number 109, [2952,2187], has been stored successfully
# AVO attributes for trace number 110, [2952,2188], has been stored successfully
# AVO attributes for trace number 111, [2952,2189], has been stored successfully
# AVO attributes for trace number 112, [2952,2190], has been stored successfully
# AVO attributes for trace number 113, [2952,2191], has been stored successfully
# AVO attributes for trace number 114, [2952,2192], has been stored successfully
# AVO attributes for trace number 115, [2952,2193], has been stored successfully
# AVO attributes for trace number 116, [2952,2194], has been stored successfully
# AVO attributes for trace number 117, [2952,2195], has been stored successfully
# AVO attributes for trace number 118, [2952,2196], has been stored successfully
# AVO attributes for trace number 119, [2952,2197], has been stored successfully
# AVO attributes for trace number 121, [2952,2199], has been stored successfully
# AVO attributes for trace number 120, [2952,2198], has been stored successfully
# AVO attributes for trace number 122, [2952,2200], has been stored successfully
# AVO attributes for trace number 123, [2952,2201], has been stored successfully
# AVO attributes for trace number 125, [2952,2203], has been stored successfully
# AVO attributes for trace number 124, [2952,2202], has been stored successfully
# AVO attributes for trace number 126, [2952,2204], has been stored successfully
# AVO attributes for trace number 127, [2952,2205], has been stored successfully
# AVO attributes for trace number 128, [2952,2206], has been stored successfully
# AVO attributes for trace number 130, [2952,2208], has been stored successfully
# AVO attributes for trace number 129, [2952,2207], has been stored successfully
# AVO attributes for trace number 131, [2952,2209], has been stored successfully
# AVO attributes for trace number 132, [2952,2210], has been stored successfully
# AVO attributes for trace number 133, [2952,2211], has been stored successfully
# AVO attributes for trace number 134, [2952,2212], has been stored successfully
# AVO attributes for trace number 135, [2952,2213], has been stored successfully
# AVO attributes for trace number 136, [2952,2214], has been stored successfully
# AVO attributes for trace number 137, [2952,2215], has been stored successfully
# AVO attributes for trace number 138, [2952,2216], has been stored successfully
# AVO attributes for trace number 139, [2952,2217], has been stored successfully
# AVO attributes for trace number 140, [2952,2218], has been stored successfully
# AVO attributes for trace number 141, [2952,2219], has been stored successfully
# AVO attributes for trace number 142, [2952,2220], has been stored successfully
# AVO attributes for trace number 143, [2952,2221], has been stored successfully
# AVO attributes for trace number 144, [2952,2222], has been stored successfully
# AVO attributes for trace number 145, [2952,2223], has been stored successfully
# AVO attributes for trace number 146, [2952,2224], has been stored successfully
# AVO attributes for trace number 147, [2952,2225], has been stored successfully
# AVO attributes for trace number 148, [2952,2226], has been stored successfully
# AVO attributes for trace number 149, [2952,2227], has been stored successfully
# AVO attributes for trace number 150, [2952,2228], has been stored successfully
# AVO attributes for trace number 151, [2952,2229], has been stored successfully
# AVO attributes for trace number 153, [2953,2180], has been stored successfully
# AVO attributes for trace number 152, [2952,2230], has been stored successfully
# AVO attributes for trace number 154, [2953,2181], has been stored successfully
# AVO attributes for trace number 155, [2953,2182], has been stored successfully
# AVO attributes for trace number 156, [2953,2183], has been stored successfully
# AVO attributes for trace number 157, [2953,2184], has been stored successfully
# AVO attributes for trace number 158, [2953,2185], has been stored successfully
# AVO attributes for trace number 159, [2953,2186], has been stored successfully
# AVO attributes for trace number 160, [2953,2187], has been stored successfully
# AVO attributes for trace number 161, [2953,2188], has been stored successfully
# AVO attributes for trace number 162, [2953,2189], has been stored successfully
# AVO attributes for trace number 163, [2953,2190], has been stored successfully
# AVO attributes for trace number 164, [2953,2191], has been stored successfully
# AVO attributes for trace number 165, [2953,2192], has been stored successfully
# AVO attributes for trace number 166, [2953,2193], has been stored successfully
# AVO attributes for trace number 167, [2953,2194], has been stored successfully
# AVO attributes for trace number 168, [2953,2195], has been stored successfully
# AVO attributes for trace number 169, [2953,2196], has been stored successfully
# AVO attributes for trace number 170, [2953,2197], has been stored successfully
# AVO attributes for trace number 171, [2953,2198], has been stored successfully
# AVO attributes for trace number 172, [2953,2199], has been stored successfully
# AVO attributes for trace number 173, [2953,2200], has been stored successfully
# AVO attributes for trace number 174, [2953,2201], has been stored successfully
# AVO attributes for trace number 175, [2953,2202], has been stored successfully
# AVO attributes for trace number 176, [2953,2203], has been stored successfully
# AVO attributes for trace number 177, [2953,2204], has been stored successfully
# AVO attributes for trace number 178, [2953,2205], has been stored successfully
# AVO attributes for trace number 179, [2953,2206], has been stored successfully
# AVO attributes for trace number 180, [2953,2207], has been stored successfully
# AVO attributes for trace number 181, [2953,2208], has been stored successfully
# AVO attributes for trace number 182, [2953,2209], has been stored successfully
# AVO attributes for trace number 183, [2953,2210], has been stored successfully
# AVO attributes for trace number 184, [2953,2211], has been stored successfully
# AVO attributes for trace number 185, [2953,2212], has been stored successfully
# AVO attributes for trace number 186, [2953,2213], has been stored successfully
# AVO attributes for trace number 187, [2953,2214], has been stored successfully
# AVO attributes for trace number 189, [2953,2216], has been stored successfully
# AVO attributes for trace number 188, [2953,2215], has been stored successfully
# AVO attributes for trace number 190, [2953,2217], has been stored successfully
# AVO attributes for trace number 191, [2953,2218], has been stored successfully
# AVO attributes for trace number 193, [2953,2220], has been stored successfully
# AVO attributes for trace number 192, [2953,2219], has been stored successfully
# AVO attributes for trace number 194, [2953,2221], has been stored successfully
# AVO attributes for trace number 195, [2953,2222], has been stored successfully
# AVO attributes for trace number 197, [2953,2224], has been stored successfully
# AVO attributes for trace number 196, [2953,2223], has been stored successfully
# AVO attributes for trace number 198, [2953,2225], has been stored successfully
# AVO attributes for trace number 199, [2953,2226], has been stored successfully
# AVO attributes for trace number 201, [2953,2228], has been stored successfully
# AVO attributes for trace number 200, [2953,2227], has been stored successfully
# AVO attributes for trace number 202, [2953,2229], has been stored successfully
# AVO attributes for trace number 203, [2953,2230], has been stored successfully
# AVO attributes for trace number 204, [2954,2180], has been stored successfully
# AVO attributes for trace number 205, [2954,2181], has been stored successfully
# AVO attributes for trace number 206, [2954,2182], has been stored successfully
# AVO attributes for trace number 207, [2954,2183], has been stored successfully
# AVO attributes for trace number 208, [2954,2184], has been stored successfully
# AVO attributes for trace number 210, [2954,2186], has been stored successfully
# AVO attributes for trace number 209, [2954,2185], has been stored successfully
# AVO attributes for trace number 211, [2954,2187], has been stored successfully
# AVO attributes for trace number 213, [2954,2189], has been stored successfully
# AVO attributes for trace number 212, [2954,2188], has been stored successfully
# AVO attributes for trace number 214, [2954,2190], has been stored successfully
# AVO attributes for trace number 215, [2954,2191], has been stored successfully
# AVO attributes for trace number 216, [2954,2192], has been stored successfully
# AVO attributes for trace number 217, [2954,2193], has been stored successfully
# AVO attributes for trace number 218, [2954,2194], has been stored successfully
# AVO attributes for trace number 219, [2954,2195], has been stored successfully
# AVO attributes for trace number 220, [2954,2196], has been stored successfully
# AVO attributes for trace number 221, [2954,2197], has been stored successfully
# AVO attributes for trace number 222, [2954,2198], has been stored successfully
# AVO attributes for trace number 223, [2954,2199], has been stored successfully
# AVO attributes for trace number 224, [2954,2200], has been stored successfully
# AVO attributes for trace number 225, [2954,2201], has been stored successfully
# AVO attributes for trace number 226, [2954,2202], has been stored successfully
# AVO attributes for trace number 227, [2954,2203], has been stored successfully
# AVO attributes for trace number 228, [2954,2204], has been stored successfully
# AVO attributes for trace number 230, [2954,2206], has been stored successfully
# AVO attributes for trace number 229, [2954,2205], has been stored successfully
# AVO attributes for trace number 231, [2954,2207], has been stored successfully
# AVO attributes for trace number 232, [2954,2208], has been stored successfully
# AVO attributes for trace number 233, [2954,2209], has been stored successfully
# AVO attributes for trace number 234, [2954,2210], has been stored successfully
# AVO attributes for trace number 235, [2954,2211], has been stored successfully
# AVO attributes for trace number 236, [2954,2212], has been stored successfully
# AVO attributes for trace number 237, [2954,2213], has been stored successfully
# AVO attributes for trace number 238, [2954,2214], has been stored successfully
# AVO attributes for trace number 239, [2954,2215], has been stored successfully
# AVO attributes for trace number 240, [2954,2216], has been stored successfully
# AVO attributes for trace number 241, [2954,2217], has been stored successfully
# AVO attributes for trace number 242, [2954,2218], has been stored successfully
# AVO attributes for trace number 243, [2954,2219], has been stored successfully
# AVO attributes for trace number 244, [2954,2220], has been stored successfully
# AVO attributes for trace number 245, [2954,2221], has been stored successfully
# AVO attributes for trace number 246, [2954,2222], has been stored successfully
# AVO attributes for trace number 247, [2954,2223], has been stored successfully
# AVO attributes for trace number 248, [2954,2224], has been stored successfully
# AVO attributes for trace number 249, [2954,2225], has been stored successfully
# AVO attributes for trace number 250, [2954,2226], has been stored successfully
# AVO attributes for trace number 251, [2954,2227], has been stored successfully
# AVO attributes for trace number 252, [2954,2228], has been stored successfully
# AVO attributes for trace number 253, [2954,2229], has been stored successfully
# AVO attributes for trace number 254, [2954,2230], has been stored successfully
# AVO attributes for trace number 255, [2955,2180], has been stored successfully
# AVO attributes for trace number 256, [2955,2181], has been stored successfully
# AVO attributes for trace number 257, [2955,2182], has been stored successfully
# AVO attributes for trace number 258, [2955,2183], has been stored successfully
# AVO attributes for trace number 259, [2955,2184], has been stored successfully
# AVO attributes for trace number 260, [2955,2185], has been stored successfully
# AVO attributes for trace number 261, [2955,2186], has been stored successfully
# AVO attributes for trace number 262, [2955,2187], has been stored successfully
# AVO attributes for trace number 263, [2955,2188], has been stored successfully
# AVO attributes for trace number 264, [2955,2189], has been stored successfully
# AVO attributes for trace number 265, [2955,2190], has been stored successfully
# AVO attributes for trace number 266, [2955,2191], has been stored successfully
# AVO attributes for trace number 267, [2955,2192], has been stored successfully
# AVO attributes for trace number 268, [2955,2193], has been stored successfully
# AVO attributes for trace number 269, [2955,2194], has been stored successfully
# AVO attributes for trace number 270, [2955,2195], has been stored successfully
# AVO attributes for trace number 271, [2955,2196], has been stored successfully
# AVO attributes for trace number 272, [2955,2197], has been stored successfully
# AVO attributes for trace number 273, [2955,2198], has been stored successfully
# AVO attributes for trace number 274, [2955,2199], has been stored successfully
# AVO attributes for trace number 275, [2955,2200], has been stored successfully
# AVO attributes for trace number 276, [2955,2201], has been stored successfully
# AVO attributes for trace number 277, [2955,2202], has been stored successfully
# AVO attributes for trace number 278, [2955,2203], has been stored successfully
# AVO attributes for trace number 279, [2955,2204], has been stored successfully
# AVO attributes for trace number 280, [2955,2205], has been stored successfully
# AVO attributes for trace number 281, [2955,2206], has been stored successfully
# AVO attributes for trace number 282, [2955,2207], has been stored successfully
# AVO attributes for trace number 283, [2955,2208], has been stored successfully
# AVO attributes for trace number 284, [2955,2209], has been stored successfully
# AVO attributes for trace number 285, [2955,2210], has been stored successfully
# AVO attributes for trace number 286, [2955,2211], has been stored successfully
# AVO attributes for trace number 287, [2955,2212], has been stored successfully
# AVO attributes for trace number 288, [2955,2213], has been stored successfully
# AVO attributes for trace number 289, [2955,2214], has been stored successfully
# AVO attributes for trace number 290, [2955,2215], has been stored successfully
# AVO attributes for trace number 291, [2955,2216], has been stored successfully
# AVO attributes for trace number 293, [2955,2218], has been stored successfully
# AVO attributes for trace number 292, [2955,2217], has been stored successfully
# AVO attributes for trace number 294, [2955,2219], has been stored successfully
# AVO attributes for trace number 295, [2955,2220], has been stored successfully
# AVO attributes for trace number 296, [2955,2221], has been stored successfully
# AVO attributes for trace number 297, [2955,2222], has been stored successfully
# AVO attributes for trace number 298, [2955,2223], has been stored successfully
# AVO attributes for trace number 299, [2955,2224], has been stored successfully
# AVO attributes for trace number 300, [2955,2225], has been stored successfully
# AVO attributes for trace number 301, [2955,2226], has been stored successfully
# AVO attributes for trace number 302, [2955,2227], has been stored successfully
# AVO attributes for trace number 303, [2955,2228], has been stored successfully
# AVO attributes for trace number 305, [2955,2230], has been stored successfully
# AVO attributes for trace number 304, [2955,2229], has been stored successfully
# AVO attributes for trace number 306, [2956,2180], has been stored successfully
# AVO attributes for trace number 307, [2956,2181], has been stored successfully
# AVO attributes for trace number 308, [2956,2182], has been stored successfully
# AVO attributes for trace number 309, [2956,2183], has been stored successfully
# AVO attributes for trace number 310, [2956,2184], has been stored successfully
# AVO attributes for trace number 311, [2956,2185], has been stored successfully
# AVO attributes for trace number 312, [2956,2186], has been stored successfully
# AVO attributes for trace number 313, [2956,2187], has been stored successfully
# AVO attributes for trace number 314, [2956,2188], has been stored successfully
# AVO attributes for trace number 315, [2956,2189], has been stored successfully
# AVO attributes for trace number 316, [2956,2190], has been stored successfully
# AVO attributes for trace number 317, [2956,2191], has been stored successfully
# AVO attributes for trace number 318, [2956,2192], has been stored successfully
# AVO attributes for trace number 319, [2956,2193], has been stored successfully
# AVO attributes for trace number 320, [2956,2194], has been stored successfully
# AVO attributes for trace number 321, [2956,2195], has been stored successfully
# AVO attributes for trace number 322, [2956,2196], has been stored successfully
# AVO attributes for trace number 323, [2956,2197], has been stored successfully
# AVO attributes for trace number 324, [2956,2198], has been stored successfully
# AVO attributes for trace number 325, [2956,2199], has been stored successfully
# AVO attributes for trace number 326, [2956,2200], has been stored successfully
# AVO attributes for trace number 327, [2956,2201], has been stored successfully
# AVO attributes for trace number 328, [2956,2202], has been stored successfully
# AVO attributes for trace number 329, [2956,2203], has been stored successfully
# AVO attributes for trace number 330, [2956,2204], has been stored successfully
# AVO attributes for trace number 331, [2956,2205], has been stored successfully
# AVO attributes for trace number 332, [2956,2206], has been stored successfully
# AVO attributes for trace number 333, [2956,2207], has been stored successfully
# AVO attributes for trace number 334, [2956,2208], has been stored successfully
# AVO attributes for trace number 335, [2956,2209], has been stored successfully
# AVO attributes for trace number 336, [2956,2210], has been stored successfully
# AVO attributes for trace number 337, [2956,2211], has been stored successfully
# AVO attributes for trace number 338, [2956,2212], has been stored successfully
# AVO attributes for trace number 339, [2956,2213], has been stored successfully
# AVO attributes for trace number 340, [2956,2214], has been stored successfully
# AVO attributes for trace number 341, [2956,2215], has been stored successfully
# AVO attributes for trace number 342, [2956,2216], has been stored successfully
# AVO attributes for trace number 343, [2956,2217], has been stored successfully
# AVO attributes for trace number 344, [2956,2218], has been stored successfully
# AVO attributes for trace number 345, [2956,2219], has been stored successfully
# AVO attributes for trace number 346, [2956,2220], has been stored successfully
# AVO attributes for trace number 347, [2956,2221], has been stored successfully
# AVO attributes for trace number 348, [2956,2222], has been stored successfully
# AVO attributes for trace number 349, [2956,2223], has been stored successfully
# AVO attributes for trace number 350, [2956,2224], has been stored successfully
# AVO attributes for trace number 351, [2956,2225], has been stored successfully
# AVO attributes for trace number 352, [2956,2226], has been stored successfully
# AVO attributes for trace number 353, [2956,2227], has been stored successfully
# AVO attributes for trace number 354, [2956,2228], has been stored successfully
# AVO attributes for trace number 355, [2956,2229], has been stored successfully
# AVO attributes for trace number 356, [2956,2230], has been stored successfully
# AVO attributes for trace number 357, [2957,2180], has been stored successfully
# AVO attributes for trace number 358, [2957,2181], has been stored successfully
# AVO attributes for trace number 359, [2957,2182], has been stored successfully
# AVO attributes for trace number 360, [2957,2183], has been stored successfully
# AVO attributes for trace number 361, [2957,2184], has been stored successfully
# AVO attributes for trace number 362, [2957,2185], has been stored successfully
# AVO attributes for trace number 363, [2957,2186], has been stored successfully
# AVO attributes for trace number 364, [2957,2187], has been stored successfully
# AVO attributes for trace number 365, [2957,2188], has been stored successfully
# AVO attributes for trace number 366, [2957,2189], has been stored successfully
# AVO attributes for trace number 367, [2957,2190], has been stored successfully
# AVO attributes for trace number 368, [2957,2191], has been stored successfully
# AVO attributes for trace number 370, [2957,2193], has been stored successfully
# AVO attributes for trace number 369, [2957,2192], has been stored successfully
# AVO attributes for trace number 371, [2957,2194], has been stored successfully
# AVO attributes for trace number 372, [2957,2195], has been stored successfully
# AVO attributes for trace number 374, [2957,2197], has been stored successfully
# AVO attributes for trace number 373, [2957,2196], has been stored successfully
# AVO attributes for trace number 375, [2957,2198], has been stored successfully
# AVO attributes for trace number 376, [2957,2199], has been stored successfully
# AVO attributes for trace number 377, [2957,2200], has been stored successfully
# AVO attributes for trace number 378, [2957,2201], has been stored successfully
# AVO attributes for trace number 379, [2957,2202], has been stored successfully
# AVO attributes for trace number 380, [2957,2203], has been stored successfully
# AVO attributes for trace number 381, [2957,2204], has been stored successfully
# AVO attributes for trace number 382, [2957,2205], has been stored successfully
# AVO attributes for trace number 383, [2957,2206], has been stored successfully
# AVO attributes for trace number 384, [2957,2207], has been stored successfully
# AVO attributes for trace number 385, [2957,2208], has been stored successfully
# AVO attributes for trace number 386, [2957,2209], has been stored successfully
# AVO attributes for trace number 387, [2957,2210], has been stored successfully
# AVO attributes for trace number 388, [2957,2211], has been stored successfully
# AVO attributes for trace number 389, [2957,2212], has been stored successfully
# AVO attributes for trace number 390, [2957,2213], has been stored successfully
# AVO attributes for trace number 391, [2957,2214], has been stored successfully
# AVO attributes for trace number 392, [2957,2215], has been stored successfully
# AVO attributes for trace number 393, [2957,2216], has been stored successfully
# AVO attributes for trace number 394, [2957,2217], has been stored successfully
# AVO attributes for trace number 395, [2957,2218], has been stored successfully
# AVO attributes for trace number 396, [2957,2219], has been stored successfully
# AVO attributes for trace number 397, [2957,2220], has been stored successfully
# AVO attributes for trace number 398, [2957,2221], has been stored successfully
# AVO attributes for trace number 399, [2957,2222], has been stored successfully
# AVO attributes for trace number 400, [2957,2223], has been stored successfully
# AVO attributes for trace number 401, [2957,2224], has been stored successfully
# AVO attributes for trace number 402, [2957,2225], has been stored successfully
# AVO attributes for trace number 403, [2957,2226], has been stored successfully
# AVO attributes for trace number 404, [2957,2227], has been stored successfully
# AVO attributes for trace number 405, [2957,2228], has been stored successfully
# AVO attributes for trace number 406, [2957,2229], has been stored successfully
# AVO attributes for trace number 407, [2957,2230], has been stored successfully
# AVO attributes for trace number 408, [2958,2180], has been stored successfully
# AVO attributes for trace number 409, [2958,2181], has been stored successfully
# AVO attributes for trace number 410, [2958,2182], has been stored successfully
# AVO attributes for trace number 411, [2958,2183], has been stored successfully
# AVO attributes for trace number 412, [2958,2184], has been stored successfully
# AVO attributes for trace number 413, [2958,2185], has been stored successfully
# AVO attributes for trace number 414, [2958,2186], has been stored successfully
# AVO attributes for trace number 415, [2958,2187], has been stored successfully
# AVO attributes for trace number 416, [2958,2188], has been stored successfully
# AVO attributes for trace number 417, [2958,2189], has been stored successfully
# AVO attributes for trace number 418, [2958,2190], has been stored successfully
# AVO attributes for trace number 419, [2958,2191], has been stored successfully
# AVO attributes for trace number 420, [2958,2192], has been stored successfully
# AVO attributes for trace number 421, [2958,2193], has been stored successfully
# AVO attributes for trace number 422, [2958,2194], has been stored successfully
# AVO attributes for trace number 423, [2958,2195], has been stored successfully
# AVO attributes for trace number 424, [2958,2196], has been stored successfully
# AVO attributes for trace number 425, [2958,2197], has been stored successfully
# AVO attributes for trace number 426, [2958,2198], has been stored successfully
# AVO attributes for trace number 427, [2958,2199], has been stored successfully
# AVO attributes for trace number 428, [2958,2200], has been stored successfully
# AVO attributes for trace number 429, [2958,2201], has been stored successfully
# AVO attributes for trace number 430, [2958,2202], has been stored successfully
# AVO attributes for trace number 431, [2958,2203], has been stored successfully
# AVO attributes for trace number 432, [2958,2204], has been stored successfully
# AVO attributes for trace number 433, [2958,2205], has been stored successfully
# AVO attributes for trace number 434, [2958,2206], has been stored successfully
# AVO attributes for trace number 435, [2958,2207], has been stored successfully
# AVO attributes for trace number 436, [2958,2208], has been stored successfully
# AVO attributes for trace number 437, [2958,2209], has been stored successfully
# AVO attributes for trace number 438, [2958,2210], has been stored successfully
# AVO attributes for trace number 439, [2958,2211], has been stored successfully
# AVO attributes for trace number 440, [2958,2212], has been stored successfully
# AVO attributes for trace number 441, [2958,2213], has been stored successfully
# AVO attributes for trace number 442, [2958,2214], has been stored successfully
# AVO attributes for trace number 443, [2958,2215], has been stored successfully
# AVO attributes for trace number 444, [2958,2216], has been stored successfully
# AVO attributes for trace number 445, [2958,2217], has been stored successfully
# AVO attributes for trace number 446, [2958,2218], has been stored successfully
# AVO attributes for trace number 447, [2958,2219], has been stored successfully
# AVO attributes for trace number 448, [2958,2220], has been stored successfully
# AVO attributes for trace number 449, [2958,2221], has been stored successfully
# AVO attributes for trace number 450, [2958,2222], has been stored successfully
# AVO attributes for trace number 451, [2958,2223], has been stored successfully
# AVO attributes for trace number 453, [2958,2225], has been stored successfully
# AVO attributes for trace number 452, [2958,2224], has been stored successfully
# AVO attributes for trace number 454, [2958,2226], has been stored successfully
# AVO attributes for trace number 455, [2958,2227], has been stored successfully
# AVO attributes for trace number 456, [2958,2228], has been stored successfully
# AVO attributes for trace number 457, [2958,2229], has been stored successfully
# AVO attributes for trace number 458, [2958,2230], has been stored successfully
# AVO attributes for trace number 459, [2959,2180], has been stored successfully
# AVO attributes for trace number 460, [2959,2181], has been stored successfully
# AVO attributes for trace number 461, [2959,2182], has been stored successfully
# AVO attributes for trace number 462, [2959,2183], has been stored successfully
# AVO attributes for trace number 463, [2959,2184], has been stored successfully
# AVO attributes for trace number 465, [2959,2186], has been stored successfully
# AVO attributes for trace number 464, [2959,2185], has been stored successfully
# AVO attributes for trace number 466, [2959,2187], has been stored successfully
# AVO attributes for trace number 467, [2959,2188], has been stored successfully
# AVO attributes for trace number 468, [2959,2189], has been stored successfully
# AVO attributes for trace number 469, [2959,2190], has been stored successfully
# AVO attributes for trace number 470, [2959,2191], has been stored successfully
# AVO attributes for trace number 471, [2959,2192], has been stored successfully
# AVO attributes for trace number 472, [2959,2193], has been stored successfully
# AVO attributes for trace number 473, [2959,2194], has been stored successfully
# AVO attributes for trace number 474, [2959,2195], has been stored successfully
# AVO attributes for trace number 475, [2959,2196], has been stored successfully
# AVO attributes for trace number 476, [2959,2197], has been stored successfully
# AVO attributes for trace number 477, [2959,2198], has been stored successfully
# AVO attributes for trace number 478, [2959,2199], has been stored successfully
# AVO attributes for trace number 479, [2959,2200], has been stored successfully
# AVO attributes for trace number 480, [2959,2201], has been stored successfully
# AVO attributes for trace number 481, [2959,2202], has been stored successfully
# AVO attributes for trace number 482, [2959,2203], has been stored successfully
# AVO attributes for trace number 483, [2959,2204], has been stored successfully
# AVO attributes for trace number 484, [2959,2205], has been stored successfully
# AVO attributes for trace number 486, [2959,2207], has been stored successfully
# AVO attributes for trace number 485, [2959,2206], has been stored successfully
# AVO attributes for trace number 487, [2959,2208], has been stored successfully
# AVO attributes for trace number 488, [2959,2209], has been stored successfully
# AVO attributes for trace number 490, [2959,2211], has been stored successfully
# AVO attributes for trace number 489, [2959,2210], has been stored successfully
# AVO attributes for trace number 491, [2959,2212], has been stored successfully
# AVO attributes for trace number 492, [2959,2213], has been stored successfully
# AVO attributes for trace number 493, [2959,2214], has been stored successfully
# AVO attributes for trace number 494, [2959,2215], has been stored successfully
# AVO attributes for trace number 495, [2959,2216], has been stored successfully
# AVO attributes for trace number 496, [2959,2217], has been stored successfully
# AVO attributes for trace number 497, [2959,2218], has been stored successfully
# AVO attributes for trace number 498, [2959,2219], has been stored successfully
# AVO attributes for trace number 499, [2959,2220], has been stored successfully
# AVO attributes for trace number 500, [2959,2221], has been stored successfully
# AVO attributes for trace number 502, [2959,2223], has been stored successfully
# AVO attributes for trace number 501, [2959,2222], has been stored successfully
# AVO attributes for trace number 503, [2959,2224], has been stored successfully
# AVO attributes for trace number 504, [2959,2225], has been stored successfully
# AVO attributes for trace number 505, [2959,2226], has been stored successfully
# AVO attributes for trace number 506, [2959,2227], has been stored successfully
# AVO attributes for trace number 507, [2959,2228], has been stored successfully
# AVO attributes for trace number 508, [2959,2229], has been stored successfully
# AVO attributes for trace number 509, [2959,2230], has been stored successfully
# AVO attributes for trace number 510, [2960,2180], has been stored successfully
# AVO attributes for trace number 511, [2960,2181], has been stored successfully
# AVO attributes for trace number 512, [2960,2182], has been stored successfully
# AVO attributes for trace number 513, [2960,2183], has been stored successfully
# AVO attributes for trace number 514, [2960,2184], has been stored successfully
# AVO attributes for trace number 515, [2960,2185], has been stored successfully
# AVO attributes for trace number 516, [2960,2186], has been stored successfully
# AVO attributes for trace number 517, [2960,2187], has been stored successfully
# AVO attributes for trace number 518, [2960,2188], has been stored successfully
# AVO attributes for trace number 519, [2960,2189], has been stored successfully
# AVO attributes for trace number 520, [2960,2190], has been stored successfully
# AVO attributes for trace number 522, [2960,2192], has been stored successfully
# AVO attributes for trace number 521, [2960,2191], has been stored successfully
# AVO attributes for trace number 523, [2960,2193], has been stored successfully
# AVO attributes for trace number 524, [2960,2194], has been stored successfully
# AVO attributes for trace number 526, [2960,2196], has been stored successfully
# AVO attributes for trace number 525, [2960,2195], has been stored successfully
# AVO attributes for trace number 527, [2960,2197], has been stored successfully
# AVO attributes for trace number 528, [2960,2198], has been stored successfully
# AVO attributes for trace number 529, [2960,2199], has been stored successfully
# AVO attributes for trace number 530, [2960,2200], has been stored successfully
# AVO attributes for trace number 531, [2960,2201], has been stored successfully
# AVO attributes for trace number 532, [2960,2202], has been stored successfully
# AVO attributes for trace number 533, [2960,2203], has been stored successfully
# AVO attributes for trace number 534, [2960,2204], has been stored successfully
# AVO attributes for trace number 535, [2960,2205], has been stored successfully
# AVO attributes for trace number 536, [2960,2206], has been stored successfully
# AVO attributes for trace number 537, [2960,2207], has been stored successfully
# AVO attributes for trace number 538, [2960,2208], has been stored successfully
# AVO attributes for trace number 539, [2960,2209], has been stored successfully
# AVO attributes for trace number 540, [2960,2210], has been stored successfully
# AVO attributes for trace number 541, [2960,2211], has been stored successfully
# AVO attributes for trace number 542, [2960,2212], has been stored successfully
# AVO attributes for trace number 543, [2960,2213], has been stored successfully
# AVO attributes for trace number 544, [2960,2214], has been stored successfully
# AVO attributes for trace number 545, [2960,2215], has been stored successfully
# AVO attributes for trace number 546, [2960,2216], has been stored successfully
# AVO attributes for trace number 547, [2960,2217], has been stored successfully
# AVO attributes for trace number 548, [2960,2218], has been stored successfully
# AVO attributes for trace number 549, [2960,2219], has been stored successfully
# AVO attributes for trace number 550, [2960,2220], has been stored successfully
# AVO attributes for trace number 551, [2960,2221], has been stored successfully
# AVO attributes for trace number 552, [2960,2222], has been stored successfully
# AVO attributes for trace number 553, [2960,2223], has been stored successfully
# AVO attributes for trace number 554, [2960,2224], has been stored successfully
# AVO attributes for trace number 555, [2960,2225], has been stored successfully
# AVO attributes for trace number 556, [2960,2226], has been stored successfully
# AVO attributes for trace number 557, [2960,2227], has been stored successfully
# AVO attributes for trace number 558, [2960,2228], has been stored successfully
# AVO attributes for trace number 559, [2960,2229], has been stored successfully
# AVO attributes for trace number 560, [2960,2230], has been stored successfully
# AVO attributes for trace number 561, [2961,2180], has been stored successfully
# AVO attributes for trace number 562, [2961,2181], has been stored successfully
# AVO attributes for trace number 563, [2961,2182], has been stored successfully
# AVO attributes for trace number 564, [2961,2183], has been stored successfully
# AVO attributes for trace number 565, [2961,2184], has been stored successfully
# AVO attributes for trace number 566, [2961,2185], has been stored successfully
# AVO attributes for trace number 567, [2961,2186], has been stored successfully
# AVO attributes for trace number 568, [2961,2187], has been stored successfully
# AVO attributes for trace number 569, [2961,2188], has been stored successfully
# AVO attributes for trace number 570, [2961,2189], has been stored successfully
# AVO attributes for trace number 571, [2961,2190], has been stored successfully
# AVO attributes for trace number 572, [2961,2191], has been stored successfully
# AVO attributes for trace number 573, [2961,2192], has been stored successfully
# AVO attributes for trace number 574, [2961,2193], has been stored successfully
# AVO attributes for trace number 575, [2961,2194], has been stored successfully
# AVO attributes for trace number 576, [2961,2195], has been stored successfully
# AVO attributes for trace number 577, [2961,2196], has been stored successfully
# AVO attributes for trace number 578, [2961,2197], has been stored successfully
# AVO attributes for trace number 579, [2961,2198], has been stored successfully
# AVO attributes for trace number 580, [2961,2199], has been stored successfully
# AVO attributes for trace number 581, [2961,2200], has been stored successfully
# AVO attributes for trace number 582, [2961,2201], has been stored successfully
# AVO attributes for trace number 583, [2961,2202], has been stored successfully
# AVO attributes for trace number 584, [2961,2203], has been stored successfully
# AVO attributes for trace number 585, [2961,2204], has been stored successfully
# AVO attributes for trace number 586, [2961,2205], has been stored successfully
# AVO attributes for trace number 587, [2961,2206], has been stored successfully
# AVO attributes for trace number 588, [2961,2207], has been stored successfully
# AVO attributes for trace number 589, [2961,2208], has been stored successfully
# AVO attributes for trace number 590, [2961,2209], has been stored successfully
# AVO attributes for trace number 591, [2961,2210], has been stored successfully
# AVO attributes for trace number 592, [2961,2211], has been stored successfully
# AVO attributes for trace number 593, [2961,2212], has been stored successfully
# AVO attributes for trace number 594, [2961,2213], has been stored successfully
# AVO attributes for trace number 595, [2961,2214], has been stored successfully
# AVO attributes for trace number 596, [2961,2215], has been stored successfully
# AVO attributes for trace number 597, [2961,2216], has been stored successfully
# AVO attributes for trace number 598, [2961,2217], has been stored successfully
# AVO attributes for trace number 599, [2961,2218], has been stored successfully
# AVO attributes for trace number 600, [2961,2219], has been stored successfully
# AVO attributes for trace number 601, [2961,2220], has been stored successfully
# AVO attributes for trace number 602, [2961,2221], has been stored successfully
# AVO attributes for trace number 603, [2961,2222], has been stored successfully
# AVO attributes for trace number 604, [2961,2223], has been stored successfully
# AVO attributes for trace number 605, [2961,2224], has been stored successfully
# AVO attributes for trace number 606, [2961,2225], has been stored successfully
# AVO attributes for trace number 607, [2961,2226], has been stored successfully
# ...
# AVO attributes for trace number 2401, [2997,2184], has been stored successfully
# AVO attributes for trace number 2402, [2997,2185], has been stored successfully
# AVO attributes for trace number 2403, [2997,2186], has been stored successfully
# AVO attributes for trace number 2404, [2997,2187], has been stored successfully
# AVO attributes for trace number 2405, [2997,2188], has been stored successfully
# AVO attributes for trace number 2406, [2997,2189], has been stored successfully
# AVO attributes for trace number 2407, [2997,2190], has been stored successfully
# AVO attributes for trace number 2408, [2997,2191], has been stored successfully
# AVO attributes for trace number 2409, [2997,2192], has been stored successfully
# AVO attributes for trace number 2410, [2997,2193], has been stored successfully
# AVO attributes for trace number 2411, [2997,2194], has been stored successfully
# AVO attributes for trace number 2412, [2997,2195], has been stored successfully
# AVO attributes for trace number 2413, [2997,2196], has been stored successfully
# AVO attributes for trace number 2414, [2997,2197], has been stored successfully
# AVO attributes for trace number 2415, [2997,2198], has been stored successfully
# AVO attributes for trace number 2416, [2997,2199], has been stored successfully
# AVO attributes for trace number 2417, [2997,2200], has been stored successfully
# AVO attributes for trace number 2418, [2997,2201], has been stored successfully
# AVO attributes for trace number 2419, [2997,2202], has been stored successfully
# AVO attributes for trace number 2420, [2997,2203], has been stored successfully
# AVO attributes for trace number 2421, [2997,2204], has been stored successfully
# AVO attributes for trace number 2422, [2997,2205], has been stored successfully
# AVO attributes for trace number 2423, [2997,2206], has been stored successfully
# AVO attributes for trace number 2424, [2997,2207], has been stored successfully
# AVO attributes for trace number 2425, [2997,2208], has been stored successfully
# AVO attributes for trace number 2426, [2997,2209], has been stored successfully
# AVO attributes for trace number 2427, [2997,2210], has been stored successfully
# AVO attributes for trace number 2428, [2997,2211], has been stored successfully
# AVO attributes for trace number 2429, [2997,2212], has been stored successfully
# AVO attributes for trace number 2430, [2997,2213], has been stored successfully
# AVO attributes for trace number 2431, [2997,2214], has been stored successfully
# AVO attributes for trace number 2432, [2997,2215], has been stored successfully
# AVO attributes for trace number 2433, [2997,2216], has been stored successfully
# AVO attributes for trace number 2434, [2997,2217], has been stored successfully
# AVO attributes for trace number 2435, [2997,2218], has been stored successfully
# AVO attributes for trace number 2436, [2997,2219], has been stored successfully
# AVO attributes for trace number 2437, [2997,2220], has been stored successfully
# AVO attributes for trace number 2438, [2997,2221], has been stored successfully
# AVO attributes for trace number 2439, [2997,2222], has been stored successfully
# AVO attributes for trace number 2440, [2997,2223], has been stored successfully
# AVO attributes for trace number 2441, [2997,2224], has been stored successfully
# AVO attributes for trace number 2442, [2997,2225], has been stored successfully
# AVO attributes for trace number 2443, [2997,2226], has been stored successfully
# AVO attributes for trace number 2444, [2997,2227], has been stored successfully
# AVO attributes for trace number 2445, [2997,2228], has been stored successfully
# AVO attributes for trace number 2446, [2997,2229], has been stored successfully
# AVO attributes for trace number 2447, [2997,2230], has been stored successfully
# AVO attributes for trace number 2448, [2998,2180], has been stored successfully
# AVO attributes for trace number 2449, [2998,2181], has been stored successfully
# AVO attributes for trace number 2450, [2998,2182], has been stored successfully
# AVO attributes for trace number 2451, [2998,2183], has been stored successfully
# AVO attributes for trace number 2452, [2998,2184], has been stored successfully
# AVO attributes for trace number 2453, [2998,2185], has been stored successfully
# AVO attributes for trace number 2454, [2998,2186], has been stored successfully
# AVO attributes for trace number 2455, [2998,2187], has been stored successfully
# AVO attributes for trace number 2456, [2998,2188], has been stored successfully
# AVO attributes for trace number 2457, [2998,2189], has been stored successfully
# AVO attributes for trace number 2458, [2998,2190], has been stored successfully
# AVO attributes for trace number 2459, [2998,2191], has been stored successfully
# AVO attributes for trace number 2461, [2998,2193], has been stored successfully
# AVO attributes for trace number 2460, [2998,2192], has been stored successfully
# AVO attributes for trace number 2462, [2998,2194], has been stored successfully
# AVO attributes for trace number 2463, [2998,2195], has been stored successfully
# AVO attributes for trace number 2464, [2998,2196], has been stored successfully
# AVO attributes for trace number 2465, [2998,2197], has been stored successfully
# AVO attributes for trace number 2466, [2998,2198], has been stored successfully
# AVO attributes for trace number 2467, [2998,2199], has been stored successfully
# AVO attributes for trace number 2468, [2998,2200], has been stored successfully
# AVO attributes for trace number 2469, [2998,2201], has been stored successfully
# AVO attributes for trace number 2470, [2998,2202], has been stored successfully
# AVO attributes for trace number 2471, [2998,2203], has been stored successfully
# AVO attributes for trace number 2472, [2998,2204], has been stored successfully
# AVO attributes for trace number 2473, [2998,2205], has been stored successfully
# AVO attributes for trace number 2474, [2998,2206], has been stored successfully
# AVO attributes for trace number 2475, [2998,2207], has been stored successfully
# AVO attributes for trace number 2476, [2998,2208], has been stored successfully
# AVO attributes for trace number 2477, [2998,2209], has been stored successfully
# AVO attributes for trace number 2478, [2998,2210], has been stored successfully
# AVO attributes for trace number 2479, [2998,2211], has been stored successfully
# AVO attributes for trace number 2480, [2998,2212], has been stored successfully
# AVO attributes for trace number 2481, [2998,2213], has been stored successfully
# AVO attributes for trace number 2482, [2998,2214], has been stored successfully
# AVO attributes for trace number 2483, [2998,2215], has been stored successfully
# AVO attributes for trace number 2484, [2998,2216], has been stored successfully
# AVO attributes for trace number 2485, [2998,2217], has been stored successfully
# AVO attributes for trace number 2486, [2998,2218], has been stored successfully
# AVO attributes for trace number 2487, [2998,2219], has been stored successfully
# AVO attributes for trace number 2488, [2998,2220], has been stored successfully
# AVO attributes for trace number 2489, [2998,2221], has been stored successfully
# AVO attributes for trace number 2490, [2998,2222], has been stored successfully
# AVO attributes for trace number 2491, [2998,2223], has been stored successfully
# AVO attributes for trace number 2492, [2998,2224], has been stored successfully
# AVO attributes for trace number 2493, [2998,2225], has been stored successfully
# AVO attributes for trace number 2494, [2998,2226], has been stored successfully
# AVO attributes for trace number 2495, [2998,2227], has been stored successfully
# AVO attributes for trace number 2496, [2998,2228], has been stored successfully
# AVO attributes for trace number 2497, [2998,2229], has been stored successfully
# AVO attributes for trace number 2498, [2998,2230], has been stored successfully
# AVO attributes for trace number 2499, [2999,2180], has been stored successfully
# AVO attributes for trace number 2500, [2999,2181], has been stored successfully
# AVO attributes for trace number 2501, [2999,2182], has been stored successfully
# AVO attributes for trace number 2502, [2999,2183], has been stored successfully
# AVO attributes for trace number 2503, [2999,2184], has been stored successfully
# AVO attributes for trace number 2504, [2999,2185], has been stored successfully
# AVO attributes for trace number 2505, [2999,2186], has been stored successfully
# AVO attributes for trace number 2506, [2999,2187], has been stored successfully
# AVO attributes for trace number 2507, [2999,2188], has been stored successfully
# AVO attributes for trace number 2508, [2999,2189], has been stored successfully
# AVO attributes for trace number 2509, [2999,2190], has been stored successfully
# AVO attributes for trace number 2510, [2999,2191], has been stored successfully
# AVO attributes for trace number 2511, [2999,2192], has been stored successfully
# AVO attributes for trace number 2512, [2999,2193], has been stored successfully
# AVO attributes for trace number 2513, [2999,2194], has been stored successfully
# AVO attributes for trace number 2514, [2999,2195], has been stored successfully
# AVO attributes for trace number 2515, [2999,2196], has been stored successfully
# AVO attributes for trace number 2516, [2999,2197], has been stored successfully
# AVO attributes for trace number 2517, [2999,2198], has been stored successfully
# AVO attributes for trace number 2518, [2999,2199], has been stored successfully
# AVO attributes for trace number 2519, [2999,2200], has been stored successfully
# AVO attributes for trace number 2520, [2999,2201], has been stored successfully
# AVO attributes for trace number 2521, [2999,2202], has been stored successfully
# AVO attributes for trace number 2522, [2999,2203], has been stored successfully
# AVO attributes for trace number 2523, [2999,2204], has been stored successfully
# AVO attributes for trace number 2524, [2999,2205], has been stored successfully
# AVO attributes for trace number 2525, [2999,2206], has been stored successfully
# AVO attributes for trace number 2526, [2999,2207], has been stored successfully
# AVO attributes for trace number 2527, [2999,2208], has been stored successfully
# AVO attributes for trace number 2528, [2999,2209], has been stored successfully
# AVO attributes for trace number 2529, [2999,2210], has been stored successfully
# AVO attributes for trace number 2530, [2999,2211], has been stored successfully
# AVO attributes for trace number 2531, [2999,2212], has been stored successfully
# AVO attributes for trace number 2532, [2999,2213], has been stored successfully
# AVO attributes for trace number 2533, [2999,2214], has been stored successfully
# AVO attributes for trace number 2534, [2999,2215], has been stored successfully
# AVO attributes for trace number 2535, [2999,2216], has been stored successfully
# AVO attributes for trace number 2536, [2999,2217], has been stored successfully
# AVO attributes for trace number 2537, [2999,2218], has been stored successfully
# AVO attributes for trace number 2538, [2999,2219], has been stored successfully
# AVO attributes for trace number 2539, [2999,2220], has been stored successfully
# AVO attributes for trace number 2540, [2999,2221], has been stored successfully
# AVO attributes for trace number 2541, [2999,2222], has been stored successfully
# AVO attributes for trace number 2542, [2999,2223], has been stored successfully
# AVO attributes for trace number 2543, [2999,2224], has been stored successfully
# AVO attributes for trace number 2544, [2999,2225], has been stored successfully
# AVO attributes for trace number 2545, [2999,2226], has been stored successfully
# AVO attributes for trace number 2546, [2999,2227], has been stored successfully
# AVO attributes for trace number 2547, [2999,2228], has been stored successfully
# AVO attributes for trace number 2548, [2999,2229], has been stored successfully
# AVO attributes for trace number 2549, [2999,2230], has been stored successfully
# AVO attributes for trace number 2550, [3000,2180], has been stored successfully
# AVO attributes for trace number 2551, [3000,2181], has been stored successfully
# AVO attributes for trace number 2552, [3000,2182], has been stored successfully
# AVO attributes for trace number 2553, [3000,2183], has been stored successfully
# AVO attributes for trace number 2554, [3000,2184], has been stored successfully
# AVO attributes for trace number 2555, [3000,2185], has been stored successfully
# AVO attributes for trace number 2556, [3000,2186], has been stored successfully
# AVO attributes for trace number 2557, [3000,2187], has been stored successfully
# AVO attributes for trace number 2558, [3000,2188], has been stored successfully
# AVO attributes for trace number 2559, [3000,2189], has been stored successfully
# AVO attributes for trace number 2560, [3000,2190], has been stored successfully
# AVO attributes for trace number 2561, [3000,2191], has been stored successfully
# AVO attributes for trace number 2562, [3000,2192], has been stored successfully
# AVO attributes for trace number 2563, [3000,2193], has been stored successfully
# AVO attributes for trace number 2564, [3000,2194], has been stored successfully
# AVO attributes for trace number 2565, [3000,2195], has been stored successfully
# AVO attributes for trace number 2566, [3000,2196], has been stored successfully
# AVO attributes for trace number 2567, [3000,2197], has been stored successfully
# AVO attributes for trace number 2568, [3000,2198], has been stored successfully
# AVO attributes for trace number 2569, [3000,2199], has been stored successfully
# AVO attributes for trace number 2570, [3000,2200], has been stored successfully
# AVO attributes for trace number 2571, [3000,2201], has been stored successfully
# AVO attributes for trace number 2572, [3000,2202], has been stored successfully
# AVO attributes for trace number 2573, [3000,2203], has been stored successfully
# AVO attributes for trace number 2574, [3000,2204], has been stored successfully
# AVO attributes for trace number 2575, [3000,2205], has been stored successfully
# AVO attributes for trace number 2576, [3000,2206], has been stored successfully
# AVO attributes for trace number 2577, [3000,2207], has been stored successfully
# AVO attributes for trace number 2578, [3000,2208], has been stored successfully
# AVO attributes for trace number 2579, [3000,2209], has been stored successfully
# AVO attributes for trace number 2580, [3000,2210], has been stored successfully
# AVO attributes for trace number 2581, [3000,2211], has been stored successfully
# AVO attributes for trace number 2582, [3000,2212], has been stored successfully
# AVO attributes for trace number 2583, [3000,2213], has been stored successfully
# AVO attributes for trace number 2584, [3000,2214], has been stored successfully
# AVO attributes for trace number 2585, [3000,2215], has been stored successfully
# AVO attributes for trace number 2586, [3000,2216], has been stored successfully
# AVO attributes for trace number 2587, [3000,2217], has been stored successfully
# AVO attributes for trace number 2588, [3000,2218], has been stored successfully
# AVO attributes for trace number 2589, [3000,2219], has been stored successfully
# AVO attributes for trace number 2590, [3000,2220], has been stored successfully
# AVO attributes for trace number 2591, [3000,2221], has been stored successfully
# AVO attributes for trace number 2592, [3000,2222], has been stored successfully
# AVO attributes for trace number 2593, [3000,2223], has been stored successfully
# AVO attributes for trace number 2594, [3000,2224], has been stored successfully
# AVO attributes for trace number 2595, [3000,2225], has been stored successfully
# AVO attributes for trace number 2596, [3000,2226], has been stored successfully
# AVO attributes for trace number 2597, [3000,2227], has been stored successfully
# AVO attributes for trace number 2598, [3000,2228], has been stored successfully
# AVO attributes for trace number 2599, [3000,2229], has been stored successfully
# AVO attributes for trace number 2600, [3000,2230], has been stored successfully

# %% [markdown]
# # To DO!!:
# - cube size [X]
# - chunks, maxtask [✓]
# - store the other 3 scipy's parameters [✓]
# - vectorize the for loops [✓]
# - DelayRecordingTime: 0 [X]
# - Use dask to make dataframes [X]
